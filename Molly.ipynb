# %%
# Import dependencies
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib  import cm
import json
import os
import csv

# Tell Jupyter to show matplot plots inline
# %matplotlib inline

# %%
df = pd.read_csv('bezdekIris.data')

# %%
dfGroupby = df.groupby('class')
print dfGroupby.mean()
# Out:
#                  sepalLength  sepalWidth  pedalLength  pedalWidth
# class
# Iris-setosa            5.006       3.428        1.462       0.246
# Iris-versicolor        5.936       2.770        4.260       1.326
# Iris-virginica         6.588       2.974        5.552       2.026

# %%
plt.plot(df['sepalLength'])
plt.ylabel("Sepal Length")
plt.show()
plt.savefig('results/mollyChart.png',format='png')

# %%
plt.plot(df['sepalLength'], df['sepalWidth'], "ro")
#plt.xlabel('Sepal Length')
#plt.ylabel('Sepal Width')
plt.title('Sepal Length by Sepal Width')
plt.show()

# %%
plt.scatter(df['pedalLength'], df['pedalWidth'], c=df['class'], marker="o", cmap = cm.jet)
#plt.xlabel('Sepal Length')
#plt.ylabel('Sepal Width')
plt.title('Pedal Length by Pedal Width')
plt.show()
